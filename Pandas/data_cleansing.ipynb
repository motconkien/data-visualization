# %% [markdown]
# # Replace value
# * Replace all unwanted values
# * Replace NaN values
# * Drop columns or rows having null values

# %%
import numpy as np 
import pandas as pd

# %%
#initialize dataframe
df = pd.DataFrame({'x':[1000,1200,1100,2000,-1,1300,1200], 'y':[1000,-1,1100,1000,-2,1200,1100]})
df
# Out:
#       x     y
# 0  1000  1000
# 1  1200    -1
# 2  1100  1100
# 3  2000  1000
# 4    -1    -2
# 5  1300  1200
# 6  1200  1100

# %%
#replace value -1 to 0 and -2 to 1
#df.replace({old_var:new_var})
df['y'].replace({-1:0,-2:1})
# Out:
# 0    1000
# 1       0
# 2    1100
# 3    1000
# 4       1
# 5    1200
# 6    1100
# Name: y, dtype: int64

# %%
#replace directly in column y
df['y'].replace(-1,0,inplace=True)
df
# Out:
# /var/folders/nq/2kwnsz3s0_n7jq2trb91l5_40000gn/T/ipykernel_58354/2286873699.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['y'].replace(-1,0,inplace=True)
#       x     y
# 0  1000  1000
# 1  1200     0
# 2  1100  1100
# 3  2000  1000
# 4    -1    -2
# 5  1300  1200
# 6  1200  1100

# %%
#replace all value -1 or -2 
df = df.replace({-1:0, -2:0})
df
# Out:
#       x     y
# 0  1000  1000
# 1  1200     0
# 2  1100  1100
# 3  2000  1000
# 4     0     0
# 5  1300  1200
# 6  1200  1100

# %% [markdown]
# ## Working with Null/NaN values

# %%
em_df = pd.read_excel('data/employees.xlsx', engine='openpyxl')
em_df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100     Steven      King     SKING  515.123.4567
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4            104      Bruce     Ernst    BERNST  590.423.4568
# ..           ...        ...       ...       ...           ...
# 102          202        Pat       Fay      PFAY  603.123.6666
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777
# 104          204    Hermann      Baer     HBAER  515.123.8888
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080
# 106          206    William     Gietz    WGIETZ  515.123.8181
#
#                HIRE_DATE      JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0    2003-06-17 00:00:00     AD_PRES   24000             NaN         NaN
# 1    2005-09-21 00:00:00       AD_VP   17000             NaN       100.0
# 2    2001-01-13 00:00:00       AD_VP   17000             NaN       100.0
# 3    2006-01-03 00:00:00     IT_PROG    9000             NaN       102.0
# 4    2007-05-21 00:00:00     IT_PROG    6000             NaN       103.0
# ..                   ...         ...     ...             ...         ...
# 102  2005-08-17 00:00:00      MK_REP    6000             NaN       201.0
# 103  2002-06-07 00:00:00      HR_REP    6500             NaN       101.0
# 104  2002-06-07 00:00:00      PR_REP   10000             NaN       101.0
# 105  2002-06-07 00:00:00      AC_MGR   12008             NaN       101.0
# 106  2002-06-07 00:00:00  AC_ACCOUNT    8300             NaN       205.0
#
#      DEPARTMENT_ID
# 0             90.0
# 1             90.0
# 2             90.0
# 3             60.0
# 4             60.0
# ..             ...
# 102           20.0
# 103           40.0
# 104           70.0
# 105          110.0
# 106          110.0
#
# [107 rows x 11 columns]

# %%
em_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPLOYEE_ID     107 non-null    int64
#  1   FIRST_NAME      107 non-null    object
#  2   LAST_NAME       107 non-null    object
#  3   EMAIL           107 non-null    object
#  4   PHONE_NUMBER    107 non-null    object
#  5   HIRE_DATE       107 non-null    object
#  6   JOB_ID          107 non-null    object
#  7   SALARY          107 non-null    int64
#  8   COMMISSION_PCT  35 non-null     float64
#  9   MANAGER_ID      106 non-null    float64
#  10  DEPARTMENT_ID   106 non-null    float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 9.3+ KB

# %% [markdown]
# From info, we can see the column "COMMISSION_PCT", "MANAGER_ID", "DEPARTMENT_ID" have null values. We will double check by using isnull() method

# %%
em_df.isnull().any()
# Out:
# EMPLOYEE_ID       False
# FIRST_NAME        False
# LAST_NAME         False
# EMAIL             False
# PHONE_NUMBER      False
# HIRE_DATE         False
# JOB_ID            False
# SALARY            False
# COMMISSION_PCT     True
# MANAGER_ID         True
# DEPARTMENT_ID      True
# dtype: bool

# %% [markdown]
# False means that column has no null value, True means that column has and to confirm how many null values we have, we will use sum() as below

# %%
em_df.isnull().sum()
# Out:
# EMPLOYEE_ID        0
# FIRST_NAME         0
# LAST_NAME          0
# EMAIL              0
# PHONE_NUMBER       0
# HIRE_DATE          0
# JOB_ID             0
# SALARY             0
# COMMISSION_PCT    72
# MANAGER_ID         1
# DEPARTMENT_ID      1
# dtype: int64

# %% [markdown]
# Null valuse in column COMMISSION_PCT are 72 and MANAGER_ID, DEPARTMENT_ID is lack of 1 value

# %%
#We can also check null values corresponding column or row by using axis argument
em_df[['MANAGER_ID', 'DEPARTMENT_ID']].isnull().any(axis=1)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# Length: 107, dtype: bool

# %%
#See rows having null values
em_df[em_df[['MANAGER_ID', 'DEPARTMENT_ID']].isnull().any(axis=1)]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME   EMAIL        PHONE_NUMBER  \
# 0           100     Steven      King   SKING        515.123.4567
# 78          178  Kimberely     Grant  KGRANT  011.44.1644.429263
#
#               HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0   2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 78  2007-05-24 00:00:00   SA_REP    7000            0.15       149.0
#
#     DEPARTMENT_ID
# 0            90.0
# 78            NaN

# %% [markdown]
# There has 2 methods to fill null values:
# 1. Using the method = 'ffill': taking the front value and fill
# 2. Using the method = 'backfill': taking the next value and fill

# %%
#The null value in row 78 is replaced by value in row 77
em_copy = em_df.copy()
em_copy['DEPARTMENT_ID'] = em_copy['DEPARTMENT_ID'].fillna(method = 'ffill')
em_copy[77:79]
# Out:
# /var/folders/nq/2kwnsz3s0_n7jq2trb91l5_40000gn/T/ipykernel_58354/1462626360.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   em_copy['DEPARTMENT_ID'] = em_copy['DEPARTMENT_ID'].fillna(method = 'ffill')
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL        PHONE_NUMBER  \
# 77          177       Jack  Livingston  JLIVINGS  011.44.1644.429264
# 78          178  Kimberely       Grant    KGRANT  011.44.1644.429263
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 77  2006-04-23 00:00:00  SA_REP    8400            0.20       149.0
# 78  2007-05-24 00:00:00  SA_REP    7000            0.15       149.0
#
#     DEPARTMENT_ID
# 77           80.0
# 78           80.0

# %%
#the null value in row 0 will be replaced by value in row 1
em_copy['COMMISSION_PCT'] = em_copy['COMMISSION_PCT'].fillna(method = 'backfill')
em_copy[0:2]
# Out:
# /var/folders/nq/2kwnsz3s0_n7jq2trb91l5_40000gn/T/ipykernel_58354/2047999780.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   em_copy['COMMISSION_PCT'] = em_copy['COMMISSION_PCT'].fillna(method = 'backfill')
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             0.4         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             0.4       100.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0

# %%
#fill all null value by using fillna, for example, in column MANAGER_ID, null value will be replaced by 0
#df.fillna(new_var)
#df.fillna({old:new, old1:new1})
em_copy.fillna(0,inplace=True)
em_copy
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100     Steven      King     SKING  515.123.4567
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4            104      Bruce     Ernst    BERNST  590.423.4568
# ..           ...        ...       ...       ...           ...
# 102          202        Pat       Fay      PFAY  603.123.6666
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777
# 104          204    Hermann      Baer     HBAER  515.123.8888
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080
# 106          206    William     Gietz    WGIETZ  515.123.8181
#
#                HIRE_DATE      JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0    2003-06-17 00:00:00     AD_PRES   24000             0.4         0.0
# 1    2005-09-21 00:00:00       AD_VP   17000             0.4       100.0
# 2    2001-01-13 00:00:00       AD_VP   17000             0.4       100.0
# 3    2006-01-03 00:00:00     IT_PROG    9000             0.4       102.0
# 4    2007-05-21 00:00:00     IT_PROG    6000             0.4       103.0
# ..                   ...         ...     ...             ...         ...
# 102  2005-08-17 00:00:00      MK_REP    6000             0.0       201.0
# 103  2002-06-07 00:00:00      HR_REP    6500             0.0       101.0
# 104  2002-06-07 00:00:00      PR_REP   10000             0.0       101.0
# 105  2002-06-07 00:00:00      AC_MGR   12008             0.0       101.0
# 106  2002-06-07 00:00:00  AC_ACCOUNT    8300             0.0       205.0
#
#      DEPARTMENT_ID
# 0             90.0
# 1             90.0
# 2             90.0
# 3             60.0
# 4             60.0
# ..             ...
# 102           20.0
# 103           40.0
# 104           70.0
# 105          110.0
# 106          110.0
#
# [107 rows x 11 columns]

# %% [markdown]
# Delete row or column has null value by using dropna

# %%
em_copy2 = em_df.copy()
em_copy2
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100     Steven      King     SKING  515.123.4567
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4            104      Bruce     Ernst    BERNST  590.423.4568
# ..           ...        ...       ...       ...           ...
# 102          202        Pat       Fay      PFAY  603.123.6666
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777
# 104          204    Hermann      Baer     HBAER  515.123.8888
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080
# 106          206    William     Gietz    WGIETZ  515.123.8181
#
#                HIRE_DATE      JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0    2003-06-17 00:00:00     AD_PRES   24000             NaN         NaN
# 1    2005-09-21 00:00:00       AD_VP   17000             NaN       100.0
# 2    2001-01-13 00:00:00       AD_VP   17000             NaN       100.0
# 3    2006-01-03 00:00:00     IT_PROG    9000             NaN       102.0
# 4    2007-05-21 00:00:00     IT_PROG    6000             NaN       103.0
# ..                   ...         ...     ...             ...         ...
# 102  2005-08-17 00:00:00      MK_REP    6000             NaN       201.0
# 103  2002-06-07 00:00:00      HR_REP    6500             NaN       101.0
# 104  2002-06-07 00:00:00      PR_REP   10000             NaN       101.0
# 105  2002-06-07 00:00:00      AC_MGR   12008             NaN       101.0
# 106  2002-06-07 00:00:00  AC_ACCOUNT    8300             NaN       205.0
#
#      DEPARTMENT_ID
# 0             90.0
# 1             90.0
# 2             90.0
# 3             60.0
# 4             60.0
# ..             ...
# 102           20.0
# 103           40.0
# 104           70.0
# 105          110.0
# 106          110.0
#
# [107 rows x 11 columns]

# %%
#delete all rows having null values
drop_all = em_copy2.dropna(axis=0)
drop_all
# Out:
#     EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL        PHONE_NUMBER  \
# 45          145         John     Russell   JRUSSEL  011.44.1344.429268
# 46          146        Karen    Partners  KPARTNER  011.44.1344.467268
# 47          147      Alberto   Errazuriz  AERRAZUR  011.44.1344.429278
# 48          148       Gerald   Cambrault  GCAMBRAU  011.44.1344.619268
# 49          149        Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018
# 50          150        Peter      Tucker   PTUCKER  011.44.1344.129268
# 51          151        David   Bernstein  DBERNSTE  011.44.1344.345268
# 52          152        Peter        Hall     PHALL  011.44.1344.478968
# 53          153  Christopher       Olsen    COLSEN  011.44.1344.498718
# 54          154      Nanette   Cambrault  NCAMBRAU  011.44.1344.987668
# 55          155       Oliver     Tuvault  OTUVAULT  011.44.1344.486508
# 56          156      Janette        King     JKING  011.44.1345.429268
# 57          157      Patrick       Sully    PSULLY  011.44.1345.929268
# 58          158        Allan      McEwen   AMCEWEN  011.44.1345.829268
# 59          159      Lindsey       Smith    LSMITH  011.44.1345.729268
# 60          160       Louise       Doran    LDORAN  011.44.1345.629268
# 61          161       Sarath      Sewall   SSEWALL  011.44.1345.529268
# 62          162        Clara     Vishney  CVISHNEY  011.44.1346.129268
# 63          163     Danielle      Greene   DGREENE  011.44.1346.229268
# 64          164       Mattea     Marvins  MMARVINS  011.44.1346.329268
# 65          165        David         Lee      DLEE  011.44.1346.529268
# 66          166       Sundar        Ande     SANDE  011.44.1346.629268
# 67          167         Amit       Banda    ABANDA  011.44.1346.729268
# 68          168         Lisa        Ozer     LOZER  011.44.1343.929268
# 69          169     Harrison       Bloom    HBLOOM  011.44.1343.829268
# 70          170       Tayler         Fox      TFOX  011.44.1343.729268
# 71          171      William       Smith    WSMITH  011.44.1343.629268
# 72          172    Elizabeth       Bates    EBATES  011.44.1343.529268
# 73          173      Sundita       Kumar    SKUMAR  011.44.1343.329268
# 74          174        Ellen        Abel     EABEL  011.44.1644.429267
# 75          175       Alyssa      Hutton   AHUTTON  011.44.1644.429266
# 76          176     Jonathon      Taylor   JTAYLOR  011.44.1644.429265
# 77          177         Jack  Livingston  JLIVINGS  011.44.1644.429264
# 79          179      Charles     Johnson  CJOHNSON  011.44.1644.429262
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 45  2004-10-01 00:00:00  SA_MAN   14000            0.40       100.0
# 46  2005-01-05 00:00:00  SA_MAN   13500            0.30       100.0
# 47  2005-03-10 00:00:00  SA_MAN   12000            0.30       100.0
# 48  2007-10-15 00:00:00  SA_MAN   11000            0.30       100.0
# 49  2008-01-29 00:00:00  SA_MAN   10500            0.20       100.0
# 50  2005-01-30 00:00:00  SA_REP   10000            0.30       145.0
# 51  2005-03-24 00:00:00  SA_REP    9500            0.25       145.0
# 52  2005-08-20 00:00:00  SA_REP    9000            0.25       145.0
# 53  2006-03-30 00:00:00  SA_REP    8000            0.20       145.0
# 54  2006-12-09 00:00:00  SA_REP    7500            0.20       145.0
# 55  2007-11-23 00:00:00  SA_REP    7000            0.15       145.0
# 56  2004-01-30 00:00:00  SA_REP   10000            0.35       146.0
# 57  2004-03-04 00:00:00  SA_REP    9500            0.35       146.0
# 58  2004-08-01 00:00:00  SA_REP    9000            0.35       146.0
# 59  2005-03-10 00:00:00  SA_REP    8000            0.30       146.0
# 60  2005-12-15 00:00:00  SA_REP    7500            0.30       146.0
# 61  2006-11-03 00:00:00  SA_REP    7000            0.25       146.0
# 62  2005-11-11 00:00:00  SA_REP   10500            0.25       147.0
# 63  2007-03-19 00:00:00  SA_REP    9500            0.15       147.0
# 64  2008-01-24 00:00:00  SA_REP    7200            0.10       147.0
# 65  2008-02-23 00:00:00  SA_REP    6800            0.10       147.0
# 66  2008-03-24 00:00:00  SA_REP    6400            0.10       147.0
# 67  2008-04-21 00:00:00  SA_REP    6200            0.10       147.0
# 68  2005-03-11 00:00:00  SA_REP   11500            0.25       148.0
# 69  2006-03-23 00:00:00  SA_REP   10000            0.20       148.0
# 70  2006-01-24 00:00:00  SA_REP    9600            0.20       148.0
# 71  2007-02-23 00:00:00  SA_REP    7400            0.15       148.0
# 72  2007-03-24 00:00:00  SA_REP    7300            0.15       148.0
# 73  2008-04-21 00:00:00  SA_REP    6100            0.10       148.0
# 74  2004-05-11 00:00:00  SA_REP   11000            0.30       149.0
# 75  2005-03-19 00:00:00  SA_REP    8800            0.25       149.0
# 76  2006-03-24 00:00:00  SA_REP    8600            0.20       149.0
# 77  2006-04-23 00:00:00  SA_REP    8400            0.20       149.0
# 79  2008-01-04 00:00:00  SA_REP    6200            0.10       149.0
#
#     DEPARTMENT_ID
# 45           80.0
# 46           80.0
# 47           80.0
# 48           80.0
# 49           80.0
# 50           80.0
# 51           80.0
# 52           80.0
# 53           80.0
# 54           80.0
# 55           80.0
# 56           80.0
# 57           80.0
# 58           80.0
# 59           80.0
# 60           80.0
# 61           80.0
# 62           80.0
# 63           80.0
# 64           80.0
# 65           80.0
# 66           80.0
# 67           80.0
# 68           80.0
# 69           80.0
# 70           80.0
# 71           80.0
# 72           80.0
# 73           80.0
# 74           80.0
# 75           80.0
# 76           80.0
# 77           80.0
# 79           80.0

# %%
#drop column has null values
drop_col = em_copy2.dropna(axis=1)
drop_col
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100     Steven      King     SKING  515.123.4567
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4            104      Bruce     Ernst    BERNST  590.423.4568
# ..           ...        ...       ...       ...           ...
# 102          202        Pat       Fay      PFAY  603.123.6666
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777
# 104          204    Hermann      Baer     HBAER  515.123.8888
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080
# 106          206    William     Gietz    WGIETZ  515.123.8181
#
#                HIRE_DATE      JOB_ID  SALARY
# 0    2003-06-17 00:00:00     AD_PRES   24000
# 1    2005-09-21 00:00:00       AD_VP   17000
# 2    2001-01-13 00:00:00       AD_VP   17000
# 3    2006-01-03 00:00:00     IT_PROG    9000
# 4    2007-05-21 00:00:00     IT_PROG    6000
# ..                   ...         ...     ...
# 102  2005-08-17 00:00:00      MK_REP    6000
# 103  2002-06-07 00:00:00      HR_REP    6500
# 104  2002-06-07 00:00:00      PR_REP   10000
# 105  2002-06-07 00:00:00      AC_MGR   12008
# 106  2002-06-07 00:00:00  AC_ACCOUNT    8300
#
# [107 rows x 8 columns]

# %%
#drop rows values corresponding cols has null values
em_copy2.dropna(subset='COMMISSION_PCT')
# Out:
#     EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL        PHONE_NUMBER  \
# 45          145         John     Russell   JRUSSEL  011.44.1344.429268
# 46          146        Karen    Partners  KPARTNER  011.44.1344.467268
# 47          147      Alberto   Errazuriz  AERRAZUR  011.44.1344.429278
# 48          148       Gerald   Cambrault  GCAMBRAU  011.44.1344.619268
# 49          149        Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018
# 50          150        Peter      Tucker   PTUCKER  011.44.1344.129268
# 51          151        David   Bernstein  DBERNSTE  011.44.1344.345268
# 52          152        Peter        Hall     PHALL  011.44.1344.478968
# 53          153  Christopher       Olsen    COLSEN  011.44.1344.498718
# 54          154      Nanette   Cambrault  NCAMBRAU  011.44.1344.987668
# 55          155       Oliver     Tuvault  OTUVAULT  011.44.1344.486508
# 56          156      Janette        King     JKING  011.44.1345.429268
# 57          157      Patrick       Sully    PSULLY  011.44.1345.929268
# 58          158        Allan      McEwen   AMCEWEN  011.44.1345.829268
# 59          159      Lindsey       Smith    LSMITH  011.44.1345.729268
# 60          160       Louise       Doran    LDORAN  011.44.1345.629268
# 61          161       Sarath      Sewall   SSEWALL  011.44.1345.529268
# 62          162        Clara     Vishney  CVISHNEY  011.44.1346.129268
# 63          163     Danielle      Greene   DGREENE  011.44.1346.229268
# 64          164       Mattea     Marvins  MMARVINS  011.44.1346.329268
# 65          165        David         Lee      DLEE  011.44.1346.529268
# 66          166       Sundar        Ande     SANDE  011.44.1346.629268
# 67          167         Amit       Banda    ABANDA  011.44.1346.729268
# 68          168         Lisa        Ozer     LOZER  011.44.1343.929268
# 69          169     Harrison       Bloom    HBLOOM  011.44.1343.829268
# 70          170       Tayler         Fox      TFOX  011.44.1343.729268
# 71          171      William       Smith    WSMITH  011.44.1343.629268
# 72          172    Elizabeth       Bates    EBATES  011.44.1343.529268
# 73          173      Sundita       Kumar    SKUMAR  011.44.1343.329268
# 74          174        Ellen        Abel     EABEL  011.44.1644.429267
# 75          175       Alyssa      Hutton   AHUTTON  011.44.1644.429266
# 76          176     Jonathon      Taylor   JTAYLOR  011.44.1644.429265
# 77          177         Jack  Livingston  JLIVINGS  011.44.1644.429264
# 78          178    Kimberely       Grant    KGRANT  011.44.1644.429263
# 79          179      Charles     Johnson  CJOHNSON  011.44.1644.429262
#
#               HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 45  2004-10-01 00:00:00  SA_MAN   14000            0.40       100.0
# 46  2005-01-05 00:00:00  SA_MAN   13500            0.30       100.0
# 47  2005-03-10 00:00:00  SA_MAN   12000            0.30       100.0
# 48  2007-10-15 00:00:00  SA_MAN   11000            0.30       100.0
# 49  2008-01-29 00:00:00  SA_MAN   10500            0.20       100.0
# 50  2005-01-30 00:00:00  SA_REP   10000            0.30       145.0
# 51  2005-03-24 00:00:00  SA_REP    9500            0.25       145.0
# 52  2005-08-20 00:00:00  SA_REP    9000            0.25       145.0
# 53  2006-03-30 00:00:00  SA_REP    8000            0.20       145.0
# 54  2006-12-09 00:00:00  SA_REP    7500            0.20       145.0
# 55  2007-11-23 00:00:00  SA_REP    7000            0.15       145.0
# 56  2004-01-30 00:00:00  SA_REP   10000            0.35       146.0
# 57  2004-03-04 00:00:00  SA_REP    9500            0.35       146.0
# 58  2004-08-01 00:00:00  SA_REP    9000            0.35       146.0
# 59  2005-03-10 00:00:00  SA_REP    8000            0.30       146.0
# 60  2005-12-15 00:00:00  SA_REP    7500            0.30       146.0
# 61  2006-11-03 00:00:00  SA_REP    7000            0.25       146.0
# 62  2005-11-11 00:00:00  SA_REP   10500            0.25       147.0
# 63  2007-03-19 00:00:00  SA_REP    9500            0.15       147.0
# 64  2008-01-24 00:00:00  SA_REP    7200            0.10       147.0
# 65  2008-02-23 00:00:00  SA_REP    6800            0.10       147.0
# 66  2008-03-24 00:00:00  SA_REP    6400            0.10       147.0
# 67  2008-04-21 00:00:00  SA_REP    6200            0.10       147.0
# 68  2005-03-11 00:00:00  SA_REP   11500            0.25       148.0
# 69  2006-03-23 00:00:00  SA_REP   10000            0.20       148.0
# 70  2006-01-24 00:00:00  SA_REP    9600            0.20       148.0
# 71  2007-02-23 00:00:00  SA_REP    7400            0.15       148.0
# 72  2007-03-24 00:00:00  SA_REP    7300            0.15       148.0
# 73  2008-04-21 00:00:00  SA_REP    6100            0.10       148.0
# 74  2004-05-11 00:00:00  SA_REP   11000            0.30       149.0
# 75  2005-03-19 00:00:00  SA_REP    8800            0.25       149.0
# 76  2006-03-24 00:00:00  SA_REP    8600            0.20       149.0
# 77  2006-04-23 00:00:00  SA_REP    8400            0.20       149.0
# 78  2007-05-24 00:00:00  SA_REP    7000            0.15       149.0
# 79  2008-01-04 00:00:00  SA_REP    6200            0.10       149.0
#
#     DEPARTMENT_ID
# 45           80.0
# 46           80.0
# 47           80.0
# 48           80.0
# 49           80.0
# 50           80.0
# 51           80.0
# 52           80.0
# 53           80.0
# 54           80.0
# 55           80.0
# 56           80.0
# 57           80.0
# 58           80.0
# 59           80.0
# 60           80.0
# 61           80.0
# 62           80.0
# 63           80.0
# 64           80.0
# 65           80.0
# 66           80.0
# 67           80.0
# 68           80.0
# 69           80.0
# 70           80.0
# 71           80.0
# 72           80.0
# 73           80.0
# 74           80.0
# 75           80.0
# 76           80.0
# 77           80.0
# 78            NaN
# 79           80.0
